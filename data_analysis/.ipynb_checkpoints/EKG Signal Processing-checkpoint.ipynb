# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.signal as signal
import scipy.io
import biosppy
import peakutils
# %matplotlib notebook
from matplotlib.widgets import TextBox

# %% [markdown]
# ## Load Dataset

# %%
data_real = pd.read_csv('Subject_Dataset\\TESTING_1.csv')
data = data_real['ekg'].tolist()
ekg_t = data_real['ekg_t'].tolist()
#dataset = scipy.io.loadmat('Raw_dataset\\(PVC)SVA859m.mat')
#dataset2 = scipy.io.loadmat('Raw_dataset\\NSR16420m.mat')

# %%
plt.figure()
#raw_signal = dataset['val'][0]
raw_signal = data
raw_signal = np.array(raw_signal)
signal_len = len(raw_signal)
fs = 100
t =[]
for i in ekg_t:
    t.append(i/1000)
t = np.array(t)
plt.plot(t,raw_signal)
plt.title('Raw Signal')
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Text(0.5, 1.0, 'Raw Signal')

# %%
plt.figure()
plt.plot(t,raw_signal)
detrend_signal = scipy.signal.detrend(raw_signal, axis=-1, type='linear', bp=0)
plt.plot(t,detrend_signal)
plt.legend(['Original Signal','Detrended Signal'])
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ## Signal Processing

# %%
cutoff = 30 # frekuensi cutoff
nyq = 0.5 *fs
wn = cutoff/(nyq)

b, a = signal.butter(4,wn,btype='low', analog=False)
filtered_signal = signal.filtfilt(b,a,detrend_signal)

smoothed_signal = signal.cspline1d(filtered_signal,lamb=2)

fig, ax = plt.subplots(2, sharex = True)
ax[0].plot(t,detrend_signal)
ax[0].plot(t,filtered_signal)

ax[0].set_title('Raw Signal vs Filtered Signal')

ax[1].plot(t,smoothed_signal)
ax[1].set_title('Smoothed_Signal')
print(wn)

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# 0.6

# %% [markdown]
# ##  Response Frequency

# %%
print(a)
print(b)
# Out:
# [1.         0.7820952  0.67997853 0.1826757  0.03011888]
# [0.16717927 0.66871707 1.00307561 0.66871707 0.16717927]

# %%
plt.figure()
w, h = signal.freqz(b, a, worN=8000)
plt.plot(0.5*fs*w/np.pi, np.abs(h), 'b')
plt.plot(cutoff, 0.5*np.sqrt(2), 'ko')
plt.axvline(cutoff, color='k')
plt.xlim(0, 0.5*fs)
plt.title("Lowpass Filter Frequency Response")
plt.xlabel('Frequency [Hz]')
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ##  Deteksi R-peak

# %% [markdown]
# ##  SSF Algorithm

# %%
#rpeak
tres = 100
fig, ax = plt.subplots(3, sharex = True, sharey=True)
raw_rpeak = biosppy.signals.ecg.ssf_segmenter(signal=detrend_signal, sampling_rate=fs, threshold=tres, before=0.03, after=0.01)
raw_rpeak = raw_rpeak['rpeaks']/fs
r_index = []
for i in raw_rpeak:
    r_index.append(np.where(t == i))
    
if r_index == []:
    ax[0].plot(t,detrend_signal)
else:
    r_index = np.array(r_index)
    r_index = r_index.reshape(len(r_index))
    ax[0].plot(t,detrend_signal)
    ax[0].scatter(t[r_index],detrend_signal[r_index],c='r')
    ax[0].set_title('Raw Signal')


fil_rpeak = biosppy.signals.ecg.ssf_segmenter(signal=filtered_signal, sampling_rate=fs, threshold=tres, before=0.03, after=0.01)
fil_rpeak = fil_rpeak['rpeaks']/fs
r_index2 = []
for j in fil_rpeak:
    r_index2.append(np.where(t == j))
if r_index2 == []:
    ax[1].plot(t,filtered_signal)
else:
    r_index2 = np.array(r_index2)
    r_index2 = r_index2.reshape(len(r_index2))
    ax[1].plot(t,filtered_signal)
    ax[1].scatter(t[r_index2],filtered_signal[r_index2],c='r')
    ax[1].set_title('Filtered Signal')


sm_rpeak = biosppy.signals.ecg.ssf_segmenter(signal=smoothed_signal, sampling_rate=fs, threshold=tres, before=0.03, after=0.01)
sm_rpeak = sm_rpeak['rpeaks']/fs
r_index3 = []
for k in sm_rpeak:
    r_index3.append(np.where(t == k))
if r_index3 == []:
    ax[2].plot(t, smoothed_signal)
else:
    r_index3 = np.array(r_index3)
    r_index3 = r_index3.reshape(len(r_index3))
    ax[2].plot(t, smoothed_signal)
    ax[2].scatter(t[r_index3],smoothed_signal[r_index3],c='r')
    ax[2].set_title('Smoothed Signal')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
plt.figure()
sm_rpeak = biosppy.signals.ecg.ssf_segmenter(signal=smoothed_signal, sampling_rate=fs, threshold=tres, before=0.03, after=0.01)
sm_rpeak = sm_rpeak['rpeaks']/fs
r_index3 = []
for k in sm_rpeak:
    r_index3.append(np.where(t == k))
if r_index3 == []:
    plt.plot(t, smoothed_signal)
else:
    r_index3 = np.array(r_index3)
    r_index3 = r_index3.reshape(len(r_index3))
    plt.plot(t, smoothed_signal)
    plt.scatter(t[r_index3],smoothed_signal[r_index3],c='r')
    plt.title('Smoothed Signal')
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
#jumlah R
ssf_rpeak = sm_rpeak
ssf_rpeak
# Out:
# array([ 0.68,  1.49,  2.29,  2.76,  3.63,  4.16,  5.34,  6.29,  6.79,
#         7.99,  8.9 ,  9.39, 10.63, 11.18, 12.4 , 13.16, 13.95, 14.77,
#        15.6 , 16.43, 17.25, 18.05, 18.83, 19.63, 20.12, 21.32, 22.22,
#        22.71, 23.62, 24.49, 24.99, 26.23, 27.14, 27.63, 28.82, 29.64,
#        30.47, 31.31, 32.15, 32.97, 33.78, 34.58, 35.39, 36.22, 37.05,
#        37.86, 38.65, 39.45, 40.25, 41.06, 41.89, 42.71, 43.53, 44.31,
#        45.1 , 45.91, 46.73, 47.55, 48.35, 49.13, 49.93, 50.73, 51.55,
#        52.39, 53.2 , 54.  , 54.78, 55.58, 56.4 , 57.22, 58.04, 58.85,
#        59.63, 60.42, 61.23, 62.05, 62.53, 63.75, 64.67, 65.15, 66.36,
#        67.25, 68.1 , 68.93, 69.74, 70.53, 71.33, 72.15, 72.99, 73.82,
#        74.61, 75.4 , 76.2 ])

# %%
RR_interval = np.diff(ssf_rpeak)
RR_interval
# Out:
# array([0.81, 0.8 , 0.47, 0.87, 0.53, 1.18, 0.95, 0.5 , 1.2 , 0.91, 0.49,
#        1.24, 0.55, 1.22, 0.76, 0.79, 0.82, 0.83, 0.83, 0.82, 0.8 , 0.78,
#        0.8 , 0.49, 1.2 , 0.9 , 0.49, 0.91, 0.87, 0.5 , 1.24, 0.91, 0.49,
#        1.19, 0.82, 0.83, 0.84, 0.84, 0.82, 0.81, 0.8 , 0.81, 0.83, 0.83,
#        0.81, 0.79, 0.8 , 0.8 , 0.81, 0.83, 0.82, 0.82, 0.78, 0.79, 0.81,
#        0.82, 0.82, 0.8 , 0.78, 0.8 , 0.8 , 0.82, 0.84, 0.81, 0.8 , 0.78,
#        0.8 , 0.82, 0.82, 0.82, 0.81, 0.78, 0.79, 0.81, 0.82, 0.48, 1.22,
#        0.92, 0.48, 1.21, 0.89, 0.85, 0.83, 0.81, 0.79, 0.8 , 0.82, 0.84,
#        0.83, 0.79, 0.79, 0.8 ])

# %% [markdown]
# ## Feature Extraction

# %%
#  Heart rate (beat per minute) 60s / RR_interval
heart_rate = np.mean(60/np.mean(RR_interval))
heart_rate
# Out:
# 73.09322033898304

# %%
#  Standar deviasi dari RR interval yang sudah ternormalisasi
SDNN = np.std(RR_interval)
SDNN
# Out:
# 0.1689523484010969

# %%
#  Persentase dari selisih RR interval yang lebih dari 50ms (0.05s).
NN50 = np.sum(np.abs(np.diff(RR_interval))> 0.05)
pNN50 = (NN50/len(RR_interval)) * 100


pNN50
# Out:
# 32.608695652173914

# %%
RMSSD = (np.mean(np.diff(RR_interval) ** 2)) ** 0.5
RMSSD
# Out:
# 0.009563105743061807

# %% [markdown]
# ##  Heart Rate Stairs Plot

# %%
raw_hr = 60/RR_interval

# %%
rawhr_x= np.arange(0,len(raw_hr))

# %%
plt.figure()
plt.step(rawhr_x,raw_hr)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ## poincare plot

# %%
poin_rpeak

# %%
RR_interval

# %%
rr_len = len(RR_interval)
rr_len

# %%
r1 = RR_interval[1:rr_len]
r1

# %%
r2 = RR_interval[0:rr_len-1]
r2

# %%
plt.scatter(r1,r2)
plt.title('Poincare Plot')
plt.xlabel('r(n)')
plt.ylabel('r(n+1)')
plt.tight_layout()

# %% [markdown]
# ## Slope Sum Function

# %%
eg_rpeak = biosppy.signals.ecg.ssf_segmenter(signal=filtered_signal, sampling_rate=1000.0, threshold=2000, before=0.03, after=0.01)
eg_rpeak = eg_rpeak['rpeaks']

# %%
plt.plot(filtered_signal)
for peak in eg_rpeak:
    plt.axvline(x=peak,color='red')

# %% [markdown]
# ## gamboa_segmenter

# %%
gamboa = biosppy.signals.ecg.gamboa_segmenter(signal=smoothed_signal,tol=0.00000000001)
gamboa = gamboa['rpeaks']

# %%
plt.plot(smoothed_signal)
for peak in gamboa:
    plt.axvline(x=peak,color='red')

# %% [markdown]
# ## engzee segmenter

# %%
engzee = biosppy.signals.ecg.engzee_segmenter(signal=smoothed_signal,sampling_rate=1000,threshold=0.00000000000001)
engzee = engzee['rpeaks']

# %%
plt.plot(smoothed_signal)
for peak in engzee:
    plt.axvline(x=peak,color='red')

# %%
hamilton = biosppy.signals.ecg.hamilton_segmenter(signal=smoothed_signal, sampling_rate=1000.0)
hamilton = hamilton['rpeaks']

# %%
plt.plot(smoothed_signal)
for peak in hamilton:
    plt.axvline(x=peak,color='red')
